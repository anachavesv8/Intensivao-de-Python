# %%
# !pip install pyautogui
# !pip install pyperclip
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36613 sha256=9d0c150b6fe55ae112be05c2e1234dd1d3c2958a03f335a1d9292cb7ed623699
#   Stored in directory: c:\users\ana\appdata\local\pip\cache\wheels\d8\97\e4\d2edca92a87d3b5fbfb527264750a17b4ba297b9a7cab6e67f
# ...

# %%
import pyautogui
import pyperclip
import time

# %%
pyautogui.PAUSE = 2

#abrir nagevador

pyautogui.press("winleft")
pyautogui.write("chrome")
pyautogui.press("enter")
pyautogui.alert("Vai começar, aperte ok e não mexa em nada")

#abrir drive

link = "https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga"
pyperclip.copy(link)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(20)


# baixar base de dados atualizados

pyautogui.click(x=410, y=304, clicks=2) #abrir pasta da aula
time.sleep(5)
pyautogui.click(x=365, y=349) #clicar uma vez no arquivo
time.sleep(5)
pyautogui.click(x=1233, y=194) #clicar tres pontinhos
time.sleep(5)
pyautogui.click(x=1008, y=590) #fazer download

import pandas as pd

df = pd.read_excel(r"C:\Users\Ana\Downloads\Vendas - Dez.xlsx")
display(df)

#calculando o faturamento
faturamento = df["Valor Final"].sum()
qtde_produtos = df["Quantidade"].sum()

#criando email


pyautogui.hotkey("ctrl", "t")
pyautogui.write("https://mail.google.com/mail/u/0/?tab=rm&ogbl#inbox")
pyautogui.press("enter")
time.sleep(10)
pyautogui.click(x=78, y=202)

time.sleep(5)
pyautogui.write("chaves.ana.cris@gmail.com")

pyautogui.press("tab")
pyautogui.press("tab")

assunto = "Relatorio de Vendas"

pyperclip.copy(assunto)

pyautogui.hotkey("ctrl", "v")
pyautogui.press("tab")
texto = f"""
Prezados, bom dia

O Faturamento de ontem foi de R${faturamento:,.2f}
A quantidade de produtos foi de {qtde_produtos:,}

Curso de python automatização concluida com sucesso.

Ana

"""
#enviando email

pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("ctrl", "enter")
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
time.sleep(15)
pyautogui.position()
# Out:
# Point(x=78, y=202)
